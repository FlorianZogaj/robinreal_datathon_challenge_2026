# %% [markdown]
# # Image Embedding Pipeline — Jina CLIP v2
# Run on Colab with H100: `Runtime → Change runtime type → H100 GPU`

# %%
# !pip install -q pillow boto3 tqdm numpy python-dotenv
# Pin transformers to a version compatible with Jina CLIP v2's custom model code
# !pip install -q "transformers==4.38.2"
# Restart runtime after this cell if transformers was already loaded

# %%
from google.colab import files

print('Upload your .env file')
files.upload()  # → /content/.env

print('Upload data/listings.db')
files.upload()  # → /content/listings.db

# %%
import os
os.environ['DB_PATH'] = '/content/listings.db'

import torch
print('CUDA available:', torch.cuda.is_available())
if torch.cuda.is_available():
    print('GPU:', torch.cuda.get_device_name(0))

# %%
print('Upload scripts/embed_images_colab.py')
files.upload()  # → /content/embed_images_colab.py

# %%
# !python /content/embed_images_colab.py

# %%
# Download the result when done
files.download('image_embeddings.npz')
